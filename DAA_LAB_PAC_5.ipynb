# %% [markdown]
# **chain** **matrix** **multi**

# %%
def Matrix_multi(array,n):

  for y in range(n):
    m = [[0]*n]

  for t in range(2,n):
    for i in range(n-t):
      j = i + t
      m[i][j] =
      for k in range(i+1 , j):
        cost = m[i][k] + m[k][j] + array[i]*array[k]*array[j]

  m[i][j] = min(m[i][j] , cost)
  return m[0][n-1]



#user input
n = int(input("Enter the size of array:"))
array = []

for x in range(n):
  arr = int(input(f"Enter coin {x + 1}: "))
  array.append(arr)
Matrix_multi(arry,n)
# Out:
#   File "/tmp/ipykernel_1247/410831341.py", line 9
#     m[i][j] =
#               ^
# SyntaxError: invalid syntax
